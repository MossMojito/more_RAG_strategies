# %% [markdown]
# # 📥 AIS Sport RAG - Ingestion Demo
# This notebook demonstrates how to run the scraping and ingestion pipeline using the new modular structure.

# %%
# %load_ext autoreload
# %autoreload 2
import sys
import os

# Add src to path
sys.path.append("../src")

# %%
from ais_rag.scraper.crawler import SportsCrawler
from ais_rag.scraper.ocr_engine import OCREngine
from ais_rag.ingestion.chunker import MarkdownChunker
from ais_rag.ingestion.vector_store import VectorStore

# %% [markdown]
# ## 1. Run Scraper with OCR

# %%
crawler = SportsCrawler(username="user", password="pass")
# await crawler.scrape_urls({...})

# %% [markdown]
# ## 2. Ingest Data to ChromaDB

# %%
chunker = MarkdownChunker()
store = VectorStore()

# chunks = chunker.process_directory("../data/raw")
# store.add_chunks(chunks)
